# %% [markdown]
# # Integrated Bioinformatics Project : Flux_Balance_F_Prausnitzii
# #### Students: Michael Shawn Neilsson, Biancamaria FLorenzi, Prabhat Juyal, Tim Blokker
# #### Supervisors: Clémence Joseph, Karoline Faust

# %%
#import packages
import io
import cobra
import functions
from functions import *

# %%
#model = cobra.io.read_sbml_model('Data/f_prausnitzii.xml')
#info(model)

# %%
model=cobra.io.load_matlab_model('Data/iFpraus_v_1_0.mat')
info(model)
# Out:
# Metabolites :  833
# Reactions :  1030
# Genes :  602
# Compartments :  {'c': '', 'e': ''}
# Objective function :
#  Maximize
# 1.0*Biomass_FP - 1.0*Biomass_FP_reverse_ee33b

# %%
#https://www.thielelab.eu/in-silico-models
#model = cobra.io.read_sbml_model('Data/iFpraus_v_1_0.xml')
#(model2,errors)=(cobra.io.sbml.validate_sbml_model('Data/iFpraus_v_1_0.xml'))
#print(errors)

# %%
outputmodel= cobra.io.save_json_model(model, "Data/iFpraus.json")

# %%
#use for later perhaps 
#modelMedium = setMediumConstraints(starting_model, set_inf,
#current_inf,... medium_composition, met_Conc_mM, cellConc, t, cell-
#Weight, mediumCompounds,... mediumCompounds_lb);

# %% [markdown]
# ### What are the different reactions
# e: extracellular
#
# c: cytosol
#
# EX_ : exchange reaction
# ### Gifu Anaerobic Medium (mGAM) from:
# https://hyserve.com/files/05433_GAM-Broth_Modified_final.pdf
#
#
# - Peptone, Soya Peptone, Proteose Peptone: source of amino acids -> most likely all of them
# - Yeast extract, liver extract, meat extract, digested serum -> amino acids but also a lot of other crap, will leave this till the end
# - Dextrose -> same as glucose (https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:17634) and so -> glc_D
# - Soluble starch -> starch1200 (potatoe starch)
# - L-Tryptophane -> trp__L
# - L-Cystein Hydrochloride -> cys_L and cl and h (hydrochloride<-> HCL becomes cl and h)
# - Sodium Thioglycolate -> thiog and na1
# - L-Arginine -> arg_L
# - Vitamine K1 -> phllqne https://pubchem.ncbi.nlm.nih.gov/compound/Vitamin-K1#section=Depositor-Supplied-Synonyms
# - Hemin -> Iron and Chlorine  fe3 and cl  and perhaps ppp9 https://pubchem.ncbi.nlm.nih.gov/#query=3-%5B18-(2-carboxyethyl)-8%2C13-bis(ethenyl)-3%2C7%2C12%2C17-tetramethylporphyrin-21%2C23-diid-2-yl%5Dpropanoic%20acid%3Biron(3%2B)%3Bchloride
# - Potassium Dihydrogen Phosphate -> pi, k, h
# - Sodium Chloride -> na1 cl
#
# Digested serum : https://www.nebiolabs.com.au/-/media/catalog/datacards-or-manuals/p8108datasheet-lot0021306.pdf
#
# Generally useful page ; https://pubchem.ncbi.nlm.nih.gov/#query=Hemin
#
# check also: https://opencobra.github.io/cobratoolbox/latest/tutorials/tutorialMetabotoolsI.html

# %%
import numpy as np
aa=("ala,arg,asn,asp,asx,cys,glu,gln,glx,gly,his,ile,leu,lys,met,phe,pro,ser,thr,trp,tyr,val").split(",")
aa=[aminoacid +"_L(e)" for aminoacid in aa]
print(aa)
# Out:
# ['ala_L(e)', 'arg_L(e)', 'asn_L(e)', 'asp_L(e)', 'asx_L(e)', 'cys_L(e)', 'glu_L(e)', 'gln_L(e)', 'glx_L(e)', 'gly_L(e)', 'his_L(e)', 'ile_L(e)', 'leu_L(e)', 'lys_L(e)', 'met_L(e)', 'phe_L(e)', 'pro_L(e)', 'ser_L(e)', 'thr_L(e)', 'trp_L(e)', 'tyr_L(e)', 'val_L(e)']

# %%
model1=model.copy()
print("\nModel Medium")
#model1.objective = {model1.reactions.get_by_id('EX_ac(e)'): 1}
model1.objective = {model1.reactions.get_by_id('Biomass_FP'): 1}

print(model1.summary())
# Out:
# Model Medium
# Objective
# =========
# 1.0 Biomass_FP = 69.87885590787737
#
# Uptake
# ------
#     Metabolite          Reaction   Flux  C-Number  C-Flux
#     Lcystin[e]     EX_Lcystin(e)  3.502         6   0.05%
#         ade[e]         EX_ade(e)  864.9         5  10.85%
#      adocbl[e]      EX_adocbl(e) 0.3929        72   0.07%
#      alaala[e]      EX_alaala(e)  6.462         6   0.10%
#      alagln[e]      EX_alagln(e)  30.81         8   0.62%
#       arg-L[e]       EX_arg_L(e)   1000         6  15.05%
#       asn-L[e]       EX_asn_L(e)   16.4         4   0.16%
#         btn[e]         EX_btn(e) 0.3929        10   0.01%
#         ca2[e]         EX_ca2(e) 0.3929         0   0.00%
#          cl[e]          EX_cl(e) 0.3929         0   0.00%
#     cobalt2[e]     EX_cobalt2(e) 0.3929         0   0.00%
#      cps_fp[e]      EX_cps_fp(e) 0.3929        63   0.06%
#         cu2[e]         EX_cu2(e) 0.3929         0   0.00%
#         fe3[e]         EX_fe3(e) 0.7858         0   0.00%
#         fol[e]         EX_fol(e)  1.179        19   0.06%
#         fum[e]         EX_fum(e)   1000         4  10.03%
#       glu-L[e]       EX_glu_L(e)   1000         5  12.54%
#         gua[e]         EX_gua(e)  16.25         5   0.20%
#           h[e]           EX_h(e)    901         0   0.00%
#       his-L[e]       EX_his_L(e)  6.472         6   0.10%
#         ins[e]         EX_ins(e)  751.8        10  18.86%
#           k[e]           EX_k(e) 0.3929         0   0.00%
#      leuleu[e]      EX_leuleu(e)  15.33        12   0.46%
#       lys-L[e]       EX_lys_L(e)  23.31         6   0.35%
#       mal-L[e]       EX_mal_L(e)   1000         4  10.03%
#      metala[e]      EX_metala(e)  10.59         8   0.21%
#  metsox-S-L[e]  EX_metsox_S_L(e) 0.2368         5   0.00%
#         mg2[e]         EX_mg2(e) 0.3929         0   0.00%
#         na1[e]         EX_na1(e)   1000         0   0.00%
#         nac[e]         EX_nac(e) 0.7858         6   0.01%
#          o2[e]          EX_o2(e)  618.9         0   0.00%
#       phe-L[e]       EX_phe_L(e)  12.65         9   0.29%
#          pi[e]          EX_pi(e)  126.6         0   0.00%
#      pnto-R[e]      EX_pnto_R(e) 0.7858         9   0.02%
#       pro-L[e]       EX_pro_L(e)  15.05         5   0.19%
#        pydx[e]        EX_pydx(e) 0.3929         8   0.01%
#      ribflv[e]      EX_ribflv(e)  148.3        17   6.32%
#       ser-L[e]       EX_ser_L(e)  223.1         3   1.68%
#         so4[e]         EX_so4(e) 0.3929         0   0.00%
#         thm[e]         EX_thm(e) 0.3929        12   0.01%
#       thr-L[e]       EX_thr_L(e)  606.4         4   6.08%
#       thymd[e]       EX_thymd(e)  1.642        10   0.04%
#       trp-L[e]       EX_trp_L(e)  3.854        11   0.11%
#       tyr-L[e]       EX_tyr_L(e)  9.381         9   0.21%
#         ura[e]         EX_ura(e)  20.52         4   0.21%
#       urate[e]       EX_urate(e)  398.4         5   5.00%
#        hpyr[c]         sink_hpyr   0.05         3   0.00%
#
# Secretion
# ---------
#  Metabolite       Reaction   Flux  C-Number  C-Flux
#      na1[c]         DM_NA1  -1000         0   0.00%
#       ac[e]       EX_ac(e)  -1000         2   5.64%
#    asp-L[e]    EX_asp_L(e) -977.1         4  11.02%
#      cit[e]      EX_cit(e) -988.6         6  16.73%
#      co2[e]      EX_co2(e)  -1000         1   2.82%
#   dhor-S[e]   EX_dhor_S(e) -785.4         5  11.07%
#      for[e]      EX_for(e)   -158         1   0.45%
#      gly[e]      EX_gly(e) -527.8         2   2.98%
#   glyc-R[e]   EX_glyc_R(e)  -0.05         3   0.00%
#     hxan[e]     EX_hxan(e)  -1000         5  14.10%
#      nh4[e]      EX_nh4(e)  -1000         0   0.00%
#     orot[e]     EX_orot(e) -194.5         5   2.74%
#     ptrc[e]     EX_ptrc(e) -979.9         4  11.05%
#  rbflvrd[e]  EX_rbflvrd(e) -147.5        17   7.07%
#     succ[e]     EX_succ(e) -20.14         4   0.23%
#      xan[e]      EX_xan(e)  -1000         5  14.10%

# %%
#met_Conc_mM = [0.1;1.15;0.15;0.379;0.208;2;0.136;0.133;0.0968;0.382;0.382;0.274;0.101;0.0909;0.153;0.174;...
#0.286;0.168;0.0245;0.129;0.171;0.00863;0.00082;0.0214;0.000524;0.00227;0.082;0.00485;0.000532;0.00297;...
#0.194;0.424;0;5.33;23.81;127.26;5.63;11.11;0;0;0;1;0;0.00326;0.0073]
#customizedConstraints_lb = [-2.3460;0;0;-500;-100;-100;-100];
#customizedConstraints_ub = [500;0;0;500;500;500;500];

# %%
MediumMgam = ['ala_L_(e)', 'arg_L_(e)', 'asn_L_(e)', 'asp_L_(e)', 'asx_L_(e)', 'cys_L_(e)', 'glu_L_(e)', 'gln_L_(e)', 
              'glx_L_(e)', 'gly_L_(e)', 'his_L_(e)', 'ile_L_(e)', 'leu_L_(e)', 'lys_L_(e)', 'met_L_(e)', 'phe_L_(e)', 
              'pro_L_(e)', 'ser_L_(e)', 'thr_L_(e)', 'trp_L_(e)', 'tyr_L_(e)', 'val_L_(e)', 'glc_D_(e)', 'starch1200_(e)', 
              'cl_(e)', 'h_(e)',"ac_(e)", "so4_(e)" #'thiog_(e)'
              , 'na1_(e)', 'fe3_(e)', 'ppp9_(e)', 'h2o_(e)', 
              'pi_(e)', 'k_(e)']
MediumMgam=[mets[:-4] +"(e)" for mets in MediumMgam]
print(MediumMgam)
model2=model.copy()
model_mgam=medium(model2,MediumMgam)
print('\nMedium_mgam')
model_mgam.objective = {model_mgam.reactions.get_by_id('Biomass_FP'): 1}
print(model_mgam.summary())
# Out:
# ['ala_L(e)', 'arg_L(e)', 'asn_L(e)', 'asp_L(e)', 'asx_L(e)', 'cys_L(e)', 'glu_L(e)', 'gln_L(e)', 'glx_L(e)', 'gly_L(e)', 'his_L(e)', 'ile_L(e)', 'leu_L(e)', 'lys_L(e)', 'met_L(e)', 'phe_L(e)', 'pro_L(e)', 'ser_L(e)', 'thr_L(e)', 'trp_L(e)', 'tyr_L(e)', 'val_L(e)', 'glc_D(e)', 'starch1200(e)', 'cl(e)', 'h(e)', 'ac(e)', 'so4(e)', 'na1(e)', 'fe3(e)', 'ppp9(e)', 'h2o(e)', 'pi(e)', 'k(e)']
#
# Medium_mgam
# Objective
# =========
# 1.0 Biomass_FP = 4.3671073090673347e-17
#
# Uptake
# ------
# Metabolite   Reaction  Flux  C-Number   C-Flux
#     na1[e]  EX_na1(e) 33.47         0    0.00%
#    hpyr[c]  sink_hpyr  0.05         3  100.00%
#
# Secretion
# ---------
# Metabolite   Reaction   Flux  C-Number  C-Flux
#     na1[c]     DM_NA1 -33.47         0   0.00%
#      ac[e]   EX_ac(e)  -0.05         2  66.67%
#     co2[e]  EX_co2(e)  -0.05         1  33.33%

# %%
MediumMgam = ['ala_L_(e)', 'arg_L_(e)', 'asn_L_(e)', 'asp_L_(e)', 'asx_L_(e)', 'cys_L_(e)', 'glu_L_(e)', 'gln_L_(e)', 
              'glx_L_(e)', 'gly_L_(e)', 'his_L_(e)', 'ile_L_(e)', 'leu_L_(e)', 'lys_L_(e)', 'met_L_(e)', 'phe_L_(e)', 
              'pro_L_(e)', 'ser_L_(e)', 'thr_L_(e)', 'trp_L_(e)', 'tyr_L_(e)', 'val_L_(e)', 'glc_D_(e)', 'starch1200_(e)', 
              'cl_(e)', 'h_(e)',"ac_(e)", "so4_(e)" #'thiog_(e)'
              , 'na1_(e)', 'fe3_(e)', 'ppp9_(e)', 'h2o_(e)', 
              'pi_(e)', 'k_(e)']
MediumMgam=[mets[:-4] +"(e)" for mets in MediumMgam]
print(MediumMgam)
model2=model.copy()
model_mgam=medium(model2,MediumMgam)
print('\nMedium_mgam')
for i in range(1,len(model_mgam.reactions)):
    model_mgam.reactions[i].upper_bound=1000
    model_mgam.reactions[i].lower_bound=-1000 #does not change till 77,78
model_mgam.objective = {model_mgam.reactions.get_by_id('Biomass_FP'): 1}
print(model_mgam.summary())
# Out:
# ['ala_L(e)', 'arg_L(e)', 'asn_L(e)', 'asp_L(e)', 'asx_L(e)', 'cys_L(e)', 'glu_L(e)', 'gln_L(e)', 'glx_L(e)', 'gly_L(e)', 'his_L(e)', 'ile_L(e)', 'leu_L(e)', 'lys_L(e)', 'met_L(e)', 'phe_L(e)', 'pro_L(e)', 'ser_L(e)', 'thr_L(e)', 'trp_L(e)', 'tyr_L(e)', 'val_L(e)', 'glc_D(e)', 'starch1200(e)', 'cl(e)', 'h(e)', 'ac(e)', 'so4(e)', 'na1(e)', 'fe3(e)', 'ppp9(e)', 'h2o(e)', 'pi(e)', 'k(e)']
#
# Medium_mgam
# Objective
# =========
# 1.0 Biomass_FP = 131.51398638093758
#
# Uptake
# ------
#  Metabolite       Reaction   Flux  C-Number  C-Flux
#     4hba[c]        DM_4HBA  64.77         7   4.63%
#     3mop[e]     EX_3mop(e)  521.6         6  31.94%
#    acglu[e]    EX_acglu(e)  57.79         7   4.13%
#      ade[e]      EX_ade(e)  28.42         5   1.45%
#   adocbl[e]   EX_adocbl(e) 0.7395        72   0.54%
#   alaala[e]   EX_alaala(e)  38.38         6   2.35%
#   alahis[e]   EX_alahis(e)  12.18         9   1.12%
#   alaleu[e]   EX_alaleu(e)  57.69         9   5.30%
#    arg-L[e]    EX_arg_L(e)  37.91         6   2.32%
#      btn[e]      EX_btn(e) 0.7395        10   0.08%
#      but[e]      EX_but(e)  27.58         4   1.13%
#      ca2[e]      EX_ca2(e) 0.7395         0   0.00%
#       cl[e]       EX_cl(e) 0.7395         0   0.00%
#  cobalt2[e]  EX_cobalt2(e) 0.7395         0   0.00%
#   cps_fp[e]   EX_cps_fp(e)  27.35        63  17.59%
#      cu2[e]      EX_cu2(e) 0.7395         0   0.00%
#      fe2[e]      EX_fe2(e) 0.7395         0   0.00%
#      fe3[e]      EX_fe3(e) 0.7395         0   0.00%
#      fol[e]      EX_fol(e)  2.218        19   0.43%
#   glyc3p[e]   EX_glyc3p(e)   25.4         3   0.78%
#      gua[e]      EX_gua(e)  30.59         5   1.56%
#    ile-L[e]    EX_ile_L(e)  37.16         6   2.28%
#        k[e]        EX_k(e) 0.7395         0   0.00%
#    lys-L[e]    EX_lys_L(e)  56.03         6   3.43%
#   metala[e]   EX_metala(e)  20.38         8   1.66%
#      mg2[e]      EX_mg2(e) 0.7395         0   0.00%
#     ncam[e]     EX_ncam(e)  1.479         6   0.09%
#    phe-L[e]    EX_phe_L(e)   23.8         9   2.19%
#     plac[e]     EX_plac(e)  4.492         9   0.41%
#   pnto-R[e]   EX_pnto_R(e)  1.479         9   0.14%
#    pro-L[e]    EX_pro_L(e)  50.04         5   2.55%
#     pydx[e]     EX_pydx(e) 0.7395         8   0.06%
#   ribflv[e]   EX_ribflv(e)  1.479        17   0.26%
#      so4[e]      EX_so4(e) 0.7395         0   0.00%
#      thm[e]      EX_thm(e)  65.51        12   8.02%
#    trp-L[e]    EX_trp_L(e)  7.254        11   0.81%
#    val-L[e]    EX_val_L(e)  54.13         5   2.76%
#
# Secretion
# ---------
# Metabolite    Reaction   Flux  C-Number  C-Flux
#    cgly[e]  EX_cgly(e) -24.01         5   7.96%
#     co2[e]   EX_co2(e) -229.9         1  15.24%
#     for[e]   EX_for(e) -475.6         1  31.54%
#     gal[e]   EX_gal(e) -26.61         6  10.59%
#     gam[e]   EX_gam(e) -2.288         6   0.91%
#   glc-D[e]   EX_glc(e) -53.22         6  21.18%
#     gly[e]   EX_gly(e) -24.86         2   3.30%
#     h2s[e]   EX_h2s(e) -27.58         0   0.00%
#      o2[e]    EX_o2(e) -32.34         0   0.00%
#    orot[e]  EX_orot(e) -10.49         5   3.48%
#     ura[e]   EX_ura(e) -21.91         4   5.81%

# %%
fba = model.optimize()
fluxes = deleteNull(fba.fluxes)
print('\nActive reaction : %i which represent %f%% of the model' %(len(fluxes),len(fluxes)/len(model.reactions)*100))
print(fba.objective_value)
# Out:
# Active reaction : 364 which represent 35.339806% of the model
# 69.8788559078775

# %%
fba_model_mgam=model_mgam.optimize()
fluxes_model_mgam = deleteNull(fba_model_mgam.fluxes)
print('\nActive reaction : %i which represent %f%% of the model' %(len(fluxes_model_mgam),len(fluxes_model_mgam)/len(model_mgam.reactions)*100))
print(fba_model_mgam.objective_value)
# Out:
# Active reaction : 381 which represent 36.990291% of the model
# 131.5139863809376

# %% [markdown]
# ## Reinforced Clostridial Medium (RCM)
# http://www.oxoid.com/UK/blue/prod_detail/prod_detail.asp?pr=CM0149&org=53&c=UK&lang=EN
#
# - Yeast Extract -> lots of stuff in it, unsure of what's garbage
#
#     - Glutathione: gthrd (reduced version)
#     - 18 AA's: for concentration see MediumMainComponents
#     - Dextran: glc (it's made of glucose)
#     - Mannan: mannan or mannose -> man
#     - Trehalose: tre (not present in exchange reactions)
#     - B-vitamins: (Clemence mentioned vitamins being important so I'm putting them all in)
#         - Thiamin -> thm
#         - Riboflavin -> ribflv
#         - Niacin -> trp_L (made of tryptophan)
#         - Pantothenic Acid -> pnto_R
#         - Pyridoxine -> pydxn
#         - Biotin -> btn
#         - Folic Acid -> folate -> fol
#         - Cobalamin -> b12 / cbl1
#     - Biotin
# - Peptone -> Source of AA. We stick to bacteriological peptone
# - Glucose -> Assuming D_Glucose: glc__D
# - Soluble Starch -> strch1 or strch2
# - Sodium Chloride -> na1, cl
# - Sodium Acetate -> ac, na1
# - Cysteine Hydrochloride -> cys_L, cl, h (could also be cys_D? cys_L is more widely used)
# - Agar: Agarose (70%) and Agaropectin (30%) according to Wiki
#     - Agarose: D-galactose & 3,6-anhydro-L-galactopyranose
#         - D-galactose: gal
#         - 3,6-anhydro-L-galactopyranose: similar structure & compositon to beta-D-allose. D-Allose: all__D
#     - Agaropectin: D-galactose, L-galactose, pyruvate, sulfate
#         - D-galactose: gal
#         - L-galactose: gal__L
#         - Pyruvate: pyr (not present in exchange reactions)
#         - Sulfate: so4

# %%
model.exchanges
# Out:
# [<Reaction EX_3mop(e) at 0x21f410e8a60>,
#  <Reaction EX_4abz(e) at 0x21f410e8af0>,
#  <Reaction EX_5oxpro(e) at 0x21f410e8a30>,
#  <Reaction EX_Lcyst(e) at 0x21f410e8a90>,
#  <Reaction EX_Lcystin(e) at 0x21f410e8ac0>,
#  <Reaction EX_ac(e) at 0x21f410e8b80>,
#  <Reaction EX_acasp(e) at 0x21f410e8bb0>,
#  <Reaction EX_acgal(e) at 0x21f410e8be0>,
#  <Reaction EX_acgalglcur(e) at 0x21f410e8c10>,
#  <Reaction EX_acgam(e) at 0x21f410e8c40>,
#  <Reaction EX_acglu(e) at 0x21f410e8c70>,
#  <Reaction EX_acnam(e) at 0x21f410e8ca0>,
#  <Reaction EX_ade(e) at 0x21f410e8cd0>,
#  <Reaction EX_adocbl(e) at 0x21f410e8d00>,
#  <Reaction EX_ala_D(e) at 0x21f410e8d30>,
#  <Reaction EX_ala_L(e) at 0x21f410e8b20>,
#  <Reaction EX_alaala(e) at 0x21f410e8d60>,
#  <Reaction EX_alaasp(e) at 0x21f410e8d90>,
#  <Reaction EX_alagln(e) at 0x21f410e87f0>,
#  <Reaction EX_alaglu(e) at 0x21f410e8dc0>,
#  <Reaction EX_alagly(e) at 0x21f410e8df0>,
#  <Reaction EX_alahis(e) at 0x21f410e8e20>,
#  <Reaction EX_alaleu(e) at 0x21f410e8e50>,
#  <Reaction EX_alathr(e) at 0x21f410e8e80>,
#  <Reaction EX_arab_L(e) at 0x21f410e8eb0>,
#  <Reaction EX_arg_L(e) at 0x21f410e8ee0>,
#  <Reaction EX_asn_L(e) at 0x21f410e8f10>,
#  <Reaction EX_aso3(e) at 0x21f410e8a00>,
#  <Reaction EX_aso4(e) at 0x21f410e8f40>,
#  <Reaction EX_asp_L(e) at 0x21f410e8f70>,
#  <Reaction EX_btn(e) at 0x21f410e8fa0>,
#  <Reaction EX_but(e) at 0x21f410e8fd0>,
#  <Reaction EX_butso3(e) at 0x21f410fa040>,
#  <Reaction EX_ca2(e) at 0x21f410fa070>,
#  <Reaction EX_cbl1(e) at 0x21f410fa0a0>,
#  <Reaction EX_cbl2(e) at 0x21f410fa0d0>,
#  <Reaction EX_cd2(e) at 0x21f410fa100>,
#  <Reaction EX_cellb(e) at 0x21f410fa130>,
#  <Reaction EX_cgly(e) at 0x21f410fa160>,
#  <Reaction EX_cit(e) at 0x21f410fa190>,
#  <Reaction EX_cl(e) at 0x21f410fa1c0>,
#  <Reaction EX_co2(e) at 0x21f410fa1f0>,
#  <Reaction EX_cobalt2(e) at 0x21f410fa220>,
#  <Reaction EX_cps_fp(e) at 0x21f410fa250>,
#  <Reaction EX_cu2(e) at 0x21f410fa280>,
#  <Reaction EX_cys_L(e) at 0x21f410fa2b0>,
#  <Reaction EX_dhor_S(e) at 0x21f410fa2e0>,
#  <Reaction EX_ethso3(e) at 0x21f410fa310>,
#  <Reaction EX_fe2(e) at 0x21f410fa340>,
#  <Reaction EX_fe3(e) at 0x21f410fa370>,
#  <Reaction EX_fe3dcit(e) at 0x21f410fa3a0>,
#  <Reaction EX_fol(e) at 0x21f410fa3d0>,
#  <Reaction EX_for(e) at 0x21f410fa400>,
#  <Reaction EX_fru(e) at 0x21f410fa430>,
#  <Reaction EX_fum(e) at 0x21f410fa460>,
#  <Reaction EX_gal(e) at 0x21f410fa490>,
#  <Reaction EX_galur(e) at 0x21f410fa4c0>,
#  <Reaction EX_gam(e) at 0x21f410fa4f0>,
#  <Reaction EX_glc(e) at 0x21f410fa520>,
#  <Reaction EX_glcur(e) at 0x21f410fa550>,
#  <Reaction EX_gln_L(e) at 0x21f410fa580>,
#  <Reaction EX_glu_L(e) at 0x21f410fa5b0>,
#  <Reaction EX_gly(e) at 0x21f410fa5e0>,
#  <Reaction EX_glyasn(e) at 0x21f410fa610>,
#  <Reaction EX_glyasp(e) at 0x21f410fa640>,
#  <Reaction EX_glyc3p(e) at 0x21f410fa670>,
#  <Reaction EX_glyc_R(e) at 0x21f410fa6a0>,
#  <Reaction EX_glygln(e) at 0x21f410fa6d0>,
#  <Reaction EX_glyglu(e) at 0x21f410fa700>,
#  <Reaction EX_glygly(e) at 0x21f410fa730>,
#  <Reaction EX_glyleu(e) at 0x21f410fa760>,
#  <Reaction EX_glymet(e) at 0x21f410fa790>,
#  <Reaction EX_glyphe(e) at 0x21f410fa7c0>,
#  <Reaction EX_glypro(e) at 0x21f410fa7f0>,
#  <Reaction EX_glytyr(e) at 0x21f410fa820>,
#  <Reaction EX_gthox(e) at 0x21f410fa850>,
#  <Reaction EX_gthrd(e) at 0x21f410fa880>,
#  <Reaction EX_gua(e) at 0x21f410fa8b0>,
#  <Reaction EX_h(e) at 0x21f410fa8e0>,
#  <Reaction EX_h2o(e) at 0x21f410fa910>,
#  <Reaction EX_h2s(e) at 0x21f410fa940>,
#  <Reaction EX_hg2(e) at 0x21f410fa970>,
#  <Reaction EX_his_L(e) at 0x21f410fa9a0>,
#  <Reaction EX_hxan(e) at 0x21f410fa9d0>,
#  <Reaction EX_ile_L(e) at 0x21f410faa00>,
#  <Reaction EX_ins(e) at 0x21f410faa30>,
#  <Reaction EX_inulin(e) at 0x21f410faa60>,
#  <Reaction EX_isetac(e) at 0x21f410faa90>,
#  <Reaction EX_k(e) at 0x21f410faac0>,
#  <Reaction EX_kesto(e) at 0x21f410faaf0>,
#  <Reaction EX_kestopt(e) at 0x21f410fab20>,
#  <Reaction EX_kestottr(e) at 0x21f410fab50>,
#  <Reaction EX_lac_D(e) at 0x21f410fab80>,
#  <Reaction EX_lcts(e) at 0x21f410fabb0>,
#  <Reaction EX_leu_L(e) at 0x21f410fabe0>,
#  <Reaction EX_leugly(e) at 0x21f410fac10>,
#  <Reaction EX_leuleu(e) at 0x21f410fac40>,
#  <Reaction EX_lys_L(e) at 0x21f410fac70>,
#  <Reaction EX_mal_L(e) at 0x21f410faca0>,
#  <Reaction EX_malt(e) at 0x21f410facd0>,
#  <Reaction EX_man(e) at 0x21f410fad00>,
#  <Reaction EX_meoh(e) at 0x21f410fad30>,
#  <Reaction EX_met_D(e) at 0x21f410fad60>,
#  <Reaction EX_met_L(e) at 0x21f410fad90>,
#  <Reaction EX_metala(e) at 0x21f410fadc0>,
#  <Reaction EX_metsox_R_L(e) at 0x21f410fadf0>,
#  <Reaction EX_metsox_S_L(e) at 0x21f410fae20>,
#  <Reaction EX_mg2(e) at 0x21f410fae50>,
#  <Reaction EX_mobd(e) at 0x21f410fae80>,
#  <Reaction EX_mso3(e) at 0x21f410faeb0>,
#  <Reaction EX_na1(e) at 0x21f410faee0>,
#  <Reaction EX_nac(e) at 0x21f410faf10>,
#  <Reaction EX_ncam(e) at 0x21f410faf40>,
#  <Reaction EX_nh4(e) at 0x21f410faf70>,
#  <Reaction EX_o2(e) at 0x21f410fafa0>,
#  <Reaction EX_orn(e) at 0x21f410fafd0>,
#  <Reaction EX_orot(e) at 0x21f41110040>,
#  <Reaction EX_pb(e) at 0x21f41110070>,
#  <Reaction EX_pect(e) at 0x21f411100a0>,
#  <Reaction EX_phe_L(e) at 0x21f411100d0>,
#  <Reaction EX_pi(e) at 0x21f41110100>,
#  <Reaction EX_plac(e) at 0x21f41110130>,
#  <Reaction EX_pnto_R(e) at 0x21f41110160>,
#  <Reaction EX_pro_L(e) at 0x21f41110190>,
#  <Reaction EX_progly(e) at 0x21f411101c0>,
#  <Reaction EX_ptrc(e) at 0x21f411101f0>,
#  <Reaction EX_pydam(e) at 0x21f41110220>,
#  <Reaction EX_pydx(e) at 0x21f41110250>,
#  <Reaction EX_pydxn(e) at 0x21f41110280>,
#  <Reaction EX_rbflvrd(e) at 0x21f411102b0>,
#  <Reaction EX_ribflv(e) at 0x21f411102e0>,
#  <Reaction EX_seln(e) at 0x21f41110310>,
#  <Reaction EX_ser_L(e) at 0x21f41110340>,
#  <Reaction EX_so4(e) at 0x21f41110370>,
#  <Reaction EX_spmd(e) at 0x21f411103a0>,
#  <Reaction EX_strch1(e) at 0x21f411103d0>,
#  <Reaction EX_succ(e) at 0x21f41110400>,
#  <Reaction EX_sulfac(e) at 0x21f41110430>,
#  <Reaction EX_taur(e) at 0x21f41110460>,
#  <Reaction EX_thm(e) at 0x21f41110490>,
#  <Reaction EX_thr_L(e) at 0x21f411104c0>,
#  <Reaction EX_thymd(e) at 0x21f411104f0>,
#  <Reaction EX_trp_L(e) at 0x21f41110520>,
#  <Reaction EX_tyr_L(e) at 0x21f41110550>,
#  <Reaction EX_ura(e) at 0x21f41110580>,
#  <Reaction EX_urate(e) at 0x21f411105b0>,
#  <Reaction EX_urea(e) at 0x21f411105e0>,
#  <Reaction EX_val_L(e) at 0x21f41110610>,
#  <Reaction EX_xan(e) at 0x21f41110640>,
#  <Reaction EX_xyl_D(e) at 0x21f41110670>]

# %%
print(model.summary())
# Out:
# Objective
# =========
# 1.0 Biomass_FP = 69.8788559078775
#
# Uptake
# ------
#     Metabolite          Reaction   Flux  C-Number  C-Flux
#     Lcystin[e]     EX_Lcystin(e)  3.502         6   0.05%
#         ade[e]         EX_ade(e)  864.9         5  10.85%
#      adocbl[e]      EX_adocbl(e) 0.3929        72   0.07%
#      alaala[e]      EX_alaala(e)  6.462         6   0.10%
#      alagln[e]      EX_alagln(e)  30.81         8   0.62%
#       arg-L[e]       EX_arg_L(e)   1000         6  15.05%
#       asn-L[e]       EX_asn_L(e)   16.4         4   0.16%
#         btn[e]         EX_btn(e) 0.3929        10   0.01%
#         ca2[e]         EX_ca2(e) 0.3929         0   0.00%
#          cl[e]          EX_cl(e) 0.3929         0   0.00%
#     cobalt2[e]     EX_cobalt2(e) 0.3929         0   0.00%
#      cps_fp[e]      EX_cps_fp(e) 0.3929        63   0.06%
#         cu2[e]         EX_cu2(e) 0.3929         0   0.00%
#         fe3[e]         EX_fe3(e) 0.7858         0   0.00%
#         fol[e]         EX_fol(e)  1.179        19   0.06%
#         fum[e]         EX_fum(e)   1000         4  10.03%
#       glu-L[e]       EX_glu_L(e)   1000         5  12.54%
#         gua[e]         EX_gua(e)  16.25         5   0.20%
#           h[e]           EX_h(e)    901         0   0.00%
#       his-L[e]       EX_his_L(e)  6.472         6   0.10%
#         ins[e]         EX_ins(e)  751.8        10  18.86%
#           k[e]           EX_k(e) 0.3929         0   0.00%
#      leuleu[e]      EX_leuleu(e)  15.33        12   0.46%
#       lys-L[e]       EX_lys_L(e)  23.31         6   0.35%
#       mal-L[e]       EX_mal_L(e)   1000         4  10.03%
#      metala[e]      EX_metala(e)  10.59         8   0.21%
#  metsox-S-L[e]  EX_metsox_S_L(e) 0.2368         5   0.00%
#         mg2[e]         EX_mg2(e) 0.3929         0   0.00%
#         na1[e]         EX_na1(e)   1000         0   0.00%
#         nac[e]         EX_nac(e) 0.7858         6   0.01%
#          o2[e]          EX_o2(e)  618.9         0   0.00%
#       phe-L[e]       EX_phe_L(e)  12.65         9   0.29%
#          pi[e]          EX_pi(e)  126.6         0   0.00%
#      pnto-R[e]      EX_pnto_R(e) 0.7858         9   0.02%
#       pro-L[e]       EX_pro_L(e)  15.05         5   0.19%
#        pydx[e]        EX_pydx(e) 0.3929         8   0.01%
#      ribflv[e]      EX_ribflv(e)  148.3        17   6.32%
#       ser-L[e]       EX_ser_L(e)  223.1         3   1.68%
#         so4[e]         EX_so4(e) 0.3929         0   0.00%
#         thm[e]         EX_thm(e) 0.3929        12   0.01%
#       thr-L[e]       EX_thr_L(e)  606.4         4   6.08%
#       thymd[e]       EX_thymd(e)  1.642        10   0.04%
#       trp-L[e]       EX_trp_L(e)  3.854        11   0.11%
#       tyr-L[e]       EX_tyr_L(e)  9.381         9   0.21%
#         ura[e]         EX_ura(e)  20.52         4   0.21%
#       urate[e]       EX_urate(e)  398.4         5   5.00%
#        hpyr[c]         sink_hpyr   0.05         3   0.00%
#
# Secretion
# ---------
#  Metabolite       Reaction   Flux  C-Number  C-Flux
#      na1[c]         DM_NA1  -1000         0   0.00%
#       ac[e]       EX_ac(e)  -1000         2   5.64%
#    asp-L[e]    EX_asp_L(e) -977.1         4  11.02%
#      cit[e]      EX_cit(e) -988.6         6  16.73%
#      co2[e]      EX_co2(e)  -1000         1   2.82%
#   dhor-S[e]   EX_dhor_S(e) -785.4         5  11.07%
#      for[e]      EX_for(e)   -158         1   0.45%
#      gly[e]      EX_gly(e) -527.8         2   2.98%
#   glyc-R[e]   EX_glyc_R(e)  -0.05         3   0.00%
#     hxan[e]     EX_hxan(e)  -1000         5  14.10%
#      nh4[e]      EX_nh4(e)  -1000         0   0.00%
#     orot[e]     EX_orot(e) -194.5         5   2.74%
#     ptrc[e]     EX_ptrc(e) -979.9         4  11.05%
#  rbflvrd[e]  EX_rbflvrd(e) -147.5        17   7.07%
#     succ[e]     EX_succ(e) -20.14         4   0.23%
#      xan[e]      EX_xan(e)  -1000         5  14.10%

# %%
medium_rcm = ['4abz(e)','5oxpro(e)','ac(e)',' Lcyst(e)', 'Lcystin(e)','ade(e)', 'adocbl(e)',
              'ala_D(e)', 'ala_L(e)', 'arg_L(e)','asn_L(e)', 'asp_L(e)', 'btn(e)', 'ca2(e)', 
              'cbl1(e)','cbl2(e)','cl(e)','cobalt2(e)','cys_L(e)', 'cu2(e)','fe2(e)', 'fe3(e)',
              'fol(e)', 'gal(e)','galur(e)','glc(e)','gln_L(e)', 'glu_L(e)', 'gly(e)', 
              'gthox(e)','gthrd(e)', 'gua(e)', 'h(e)','h2o(e)','his_L(e)','hxan(e)',
              'ile_L(e)','ins(e)', 'k(e)','leu_L(e)', 'lys_L(e)','man(e)', 'mg2(e)',
              'met_D(e)', 'met_L(e)','na1(e)', 'nac(e)', 'ncam(e)','pb(e)','pect(e)', 'phe_L(e)','pi(e)',
              'pnto_R(e)', 'ptrc(e)', 'pro_L(e)', 'pydam(e)','pydx(e)', 'pydxn(e)', 
              'rbflvrd(e)', 'ribflv(e)', 'ser_L(e)', 'so4(e)','spmd(e)',
              'strch1(e)',  'taur(e)', 'thm(e)', 'thr_L(e)', 'thymd(e)', 'trp_L(e)', 
              'tyr_L(e)', 'ura(e)', 'val_L(e)', 'xan(e)']
# missing: tre, all_D, pyr.
model_rcm = medium(model.copy(), medium_rcm)
print(model_rcm.summary())
# Out:
# Objective
# =========
# 1.0 Biomass_FP = 30.73892495631308
#
# Uptake
# ------
#  Metabolite       Reaction   Flux  C-Number  C-Flux
#  Lcystin[e]  EX_Lcystin(e)   1.54         6   0.10%
#      ade[e]      EX_ade(e)    100         5   5.34%
#   adocbl[e]   EX_adocbl(e) 0.1728        72   0.13%
#    ala-D[e]    EX_ala_D(e)  5.685         3   0.18%
#    ala-L[e]    EX_ala_L(e)  18.21         3   0.58%
#    arg-L[e]    EX_arg_L(e)   15.5         6   0.99%
#    asn-L[e]    EX_asn_L(e)  7.214         4   0.31%
#      btn[e]      EX_btn(e) 0.1728        10   0.02%
#      ca2[e]      EX_ca2(e) 0.1728         0   0.00%
#       cl[e]       EX_cl(e) 0.1728         0   0.00%
#  cobalt2[e]  EX_cobalt2(e) 0.1728         0   0.00%
#      cu2[e]      EX_cu2(e) 0.1728         0   0.00%
#      fe2[e]      EX_fe2(e) 0.1728         0   0.00%
#      fe3[e]      EX_fe3(e) 0.1728         0   0.00%
#      fol[e]      EX_fol(e) 0.5185        19   0.11%
#    galur[e]    EX_galur(e)    100         6   6.41%
#    glc-D[e]      EX_glc(e)    100         6   6.41%
#    gln-L[e]    EX_gln_L(e)  13.73         5   0.73%
#    glu-L[e]    EX_glu_L(e)  4.854         5   0.26%
#      gua[e]      EX_gua(e)   7.15         5   0.38%
#      h2o[e]      EX_h2o(e)    100         0   0.00%
#    his-L[e]    EX_his_L(e)  2.847         6   0.18%
#      ins[e]      EX_ins(e)    100        10  10.68%
#        k[e]        EX_k(e) 0.1728         0   0.00%
#    leu-L[e]    EX_leu_L(e)  13.48         6   0.86%
#    lys-L[e]    EX_lys_L(e)  10.25         6   0.66%
#    met-L[e]    EX_met_L(e)  4.763         5   0.25%
#      mg2[e]      EX_mg2(e) 0.1728         0   0.00%
#      na1[e]      EX_na1(e)    100         0   0.00%
#      nac[e]      EX_nac(e) 0.3457         6   0.02%
#     pect[e]     EX_pect(e)  1.659      2535  44.91%
#    phe-L[e]    EX_phe_L(e)  5.564         9   0.53%
#       pi[e]       EX_pi(e)  57.08         0   0.00%
#   pnto-R[e]   EX_pnto_R(e) 0.3457         9   0.03%
#    pro-L[e]    EX_pro_L(e)  6.622         5   0.35%
#     pydx[e]     EX_pydx(e) 0.1728         8   0.01%
#   ribflv[e]   EX_ribflv(e)  83.09        17  15.09%
#    ser-L[e]    EX_ser_L(e)  57.84         3   1.85%
#      so4[e]      EX_so4(e) 0.1728         0   0.00%
#      thm[e]      EX_thm(e) 0.1728        12   0.02%
#    thr-L[e]    EX_thr_L(e)  34.58         4   1.48%
#    thymd[e]    EX_thymd(e) 0.8953        10   0.10%
#    trp-L[e]    EX_trp_L(e)  1.695        11   0.20%
#    tyr-L[e]    EX_tyr_L(e)  4.127         9   0.40%
#      ura[e]      EX_ura(e)  9.545         4   0.41%
#     hpyr[c]      sink_hpyr   0.05         3   0.00%
#
# Secretion
# ---------
#  Metabolite       Reaction   Flux  C-Number  C-Flux
#      na1[c]         DM_NA1   -100         0   0.00%
#       ac[e]       EX_ac(e) -852.2         2  22.95%
#    asp-L[e]    EX_asp_L(e) -114.1         4   6.15%
#      co2[e]      EX_co2(e)  -1000         1  13.47%
#   dhor-S[e]   EX_dhor_S(e) -6.643         5   0.45%
#      for[e]      EX_for(e) -33.66         1   0.45%
#   glyc-R[e]   EX_glyc_R(e)  -0.05         3   0.00%
#        h[e]        EX_h(e) -708.9         0   0.00%
#     hxan[e]     EX_hxan(e) -193.4         5  13.02%
#    lac-D[e]    EX_lac_D(e) -491.2         3  19.85%
#     meoh[e]     EX_meoh(e) -323.4         1   4.36%
#     ptrc[e]     EX_ptrc(e) -6.643         4   0.36%
#  rbflvrd[e]  EX_rbflvrd(e) -82.75        17  18.94%

# %%
for i in range(1,len(model_rcm.reactions)):
    if model_rcm.reactions[i].lower_bound == -100:
        print(model.reactions[i])
        print(model_rcm.reactions[i].upper_bound)
        print(model_rcm.reactions[i].lower_bound)
# Out:
# EX_4abz(e): 4abz[e] <=>
# 1000.0
# -100
# EX_5oxpro(e): 5oxpro[e] <=>
# 1000.0
# -100
# EX_Lcystin(e): Lcystin[e] <=>
# 1000.0
# -100
# EX_ac(e): ac[e] <=>
# 1000.0
# -100
# EX_ade(e): ade[e] <=>
# 1000.0
# -100
# EX_adocbl(e): adocbl[e] <=>
# 1000.0
# -100
# EX_ala_D(e): ala-D[e] <=>
# 1000.0
# -100
# EX_ala_L(e): ala-L[e] <=>
# 1000.0
# -100
# EX_arg_L(e): arg-L[e] <=>
# 1000.0
# -100
# EX_asn_L(e): asn-L[e] <=>
# 1000.0
# -100
# EX_asp_L(e): asp-L[e] <=>
# 1000.0
# -100
# EX_btn(e): btn[e] <=>
# 1000.0
# -100
# EX_ca2(e): ca2[e] <=>
# 1000.0
# -100
# EX_cbl1(e): cbl1[e] <=>
# 1000.0
# -100
# EX_cbl2(e): cbl2[e] <=>
# 1000.0
# -100
# EX_cl(e): cl[e] <=>
# 1000.0
# -100
# EX_cobalt2(e): cobalt2[e] <=>
# 1000.0
# -100
# EX_cu2(e): cu2[e] <=>
# 1000.0
# -100
# EX_cys_L(e): cys-L[e] <=>
# 1000.0
# -100
# EX_fe2(e): fe2[e] <=>
# 1000.0
# -100
# EX_fe3(e): fe3[e] <=>
# 1000.0
# -100
# EX_fol(e): fol[e] <=>
# 1000.0
# -100
# EX_gal(e): gal[e] <=>
# 1000.0
# -100
# EX_galur(e): galur[e] <=>
# 1000.0
# -100
# EX_glc(e): glc-D[e] <=>
# 1000.0
# -100
# EX_gln_L(e): gln-L[e] <=>
# 1000.0
# -100
# EX_glu_L(e): glu-L[e] <=>
# 1000.0
# -100
# EX_gly(e): gly[e] <=>
# 1000.0
# -100
# EX_gthox(e): gthox[e] <=>
# 1000.0
# -100
# EX_gthrd(e): gthrd[e] <=>
# 1000.0
# -100
# EX_gua(e): gua[e] <=>
# 1000.0
# -100
# EX_h(e): h[e] <=>
# 1000.0
# -100
# EX_h2o(e): h2o[e] <=>
# 1000.0
# -100
# EX_his_L(e): his-L[e] <=>
# 1000.0
# -100
# EX_hxan(e): hxan[e] <=>
# 1000.0
# -100
# EX_ile_L(e): ile-L[e] <=>
# 1000.0
# -100
# EX_ins(e): ins[e] <=>
# 1000.0
# -100
# EX_k(e): k[e] <=>
# 1000.0
# -100
# EX_leu_L(e): leu-L[e] <=>
# 1000.0
# -100
# EX_lys_L(e): lys-L[e] <=>
# 1000.0
# -100
# EX_man(e): man[e] <=>
# 1000.0
# -100
# EX_met_D(e): met-D[e] <=>
# 1000.0
# -100
# EX_met_L(e): met-L[e] <=>
# 1000.0
# -100
# EX_mg2(e): mg2[e] <=>
# 1000.0
# -100
# EX_na1(e): na1[e] <=>
# 1000.0
# -100
# EX_nac(e): nac[e] <=>
# 1000.0
# -100
# EX_ncam(e): ncam[e] <=>
# 1000.0
# -100
# EX_pb(e): pb[e] <=>
# 1000.0
# -100
# EX_pect(e): pect[e] <=>
# 1000.0
# -100
# EX_pi(e): pi[e] <=>
# 1000.0
# -100
# EX_pnto_R(e): pnto-R[e] <=>
# 1000.0
# -100
# EX_pro_L(e): pro-L[e] <=>
# 1000.0
# -100
# EX_ptrc(e): ptrc[e] <=>
# 1000.0
# -100
# EX_pydam(e): pydam[e] <=>
# 1000.0
# -100
# EX_pydx(e): pydx[e] <=>
# 1000.0
# -100
# EX_pydxn(e): pydxn[e] <=>
# 1000.0
# -100
# EX_rbflvrd(e): rbflvrd[e] <=>
# 1000.0
# -100
# EX_ribflv(e): ribflv[e] <=>
# 1000.0
# -100
# EX_ser_L(e): ser-L[e] <=>
# 1000.0
# -100
# EX_so4(e): so4[e] <=>
# 1000.0
# -100
# EX_spmd(e): spmd[e] <=>
# 1000.0
# -100
# EX_strch1(e): strch1[e] <=>
# 1000.0
# -100
# EX_taur(e): taur[e] <=>
# 1000.0
# -100
# EX_thm(e): thm[e] <=>
# 1000.0
# -100
# EX_thr_L(e): thr-L[e] <=>
# 1000.0
# -100
# EX_thymd(e): thymd[e] <=>
# 1000.0
# -100
# EX_trp_L(e): trp-L[e] <=>
# 1000.0
# -100
# EX_tyr_L(e): tyr-L[e] <=>
# 1000.0
# -100
# EX_ura(e): ura[e] <=>
# 1000.0
# -100
# EX_val_L(e): val-L[e] <=>
# 1000.0
# -100
# EX_xan(e): xan[e] <=>
# 1000.0
# -100
